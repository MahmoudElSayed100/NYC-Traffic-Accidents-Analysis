# %%
#!/usr/bin/env python

# make sure to install these packages before running:
# pip install pandas
# pip install sodapy

import pandas as pd
from sodapy import Socrata

# Replace these with your actual app token
app_token = "iQnHnn5JseouXHtXBQDeMyDch"

# Initialize the client with your app token
client = Socrata("data.cityofnewyork.us", app_token, username="mahmoudelsayed121810@gmail.com", password="M@rkseven11")

# Now you can use the authenticated client to make requests to the API.
# Example: Get the first 2000 results from the dataset "yjf6-ewhz" and convert it to a pandas DataFrame.
results = client.get("yjf6-ewhz", limit=2000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)

# %%
pd.set_option('display.max_columns', None)
results_df.head(20)
# Out:
#                  crash_date crash_time      on_street_name  \
# 0   2023-10-06T00:00:00.000      10:00     WEST 155 STREET
# 1   2023-10-06T00:00:00.000      12:22      UTOPIA PARKWAY
# 2   2023-10-06T00:00:00.000       9:02     HERKIMER STREET
# 3   2023-10-06T00:00:00.000      17:53     EAST 156 STREET
# 4   2023-10-06T00:00:00.000      16:52  WESTCHESTER AVENUE
# 5   2023-10-06T00:00:00.000      19:07                 NaN
# 6   2023-10-06T00:00:00.000      13:00      FORBELL STREET
# 7   2023-10-06T00:00:00.000      22:05     EASTERN PARKWAY
# 8   2023-10-06T00:00:00.000      10:14            3 AVENUE
# 9   2023-10-06T00:00:00.000      20:50                 NaN
# 10  2023-10-06T00:00:00.000      22:45           60 STREET
# 11  2023-10-06T00:00:00.000       7:49            4 AVENUE
# 12  2023-10-06T00:00:00.000      18:35     EAST 178 STREET
# 13  2023-10-06T00:00:00.000      16:45         KENT AVENUE
# 14  2023-10-06T00:00:00.000       8:57       BERGEN STREET
# ...
